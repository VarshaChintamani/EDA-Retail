# %% [markdown]
# # TASK - 3
# # The Sparks Foundation - GRIP
# #  VARSHA CHINTAMANI
# # EXPLORATORY DATA ANALYSIS - RETAIL

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib as mlt
import matplotlib.pyplot as plt

# %%
#load the data
df = pd.read_csv("sample.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# info about data set
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# checking any missing values are there?
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %%
#visualize the data using diffrent plots
sns.pairplot(df)
plt.show()

# %%
sns.barplot(x='Category', y='Sales', data=df)
plt.show()

# %%
sns.lineplot(x='Postal Code', y='Sales', data=df)
plt.show()

# %%
#calculate corr() B/W variables
corr=df.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
#outliers in data
sns.boxplot(x=df['Sales'])
plt.show()

# %% [markdown]
# sns.boxplot(x=df['Profit'])
# plt.show()

# %% [raw]
# #TILL HERE WE HAVE DONE VISUALIZATION OF SAMPLE SUPERSTORE USING EDA

# %%
# areas where i can make money
df=pd.read_csv("sample.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#calculate total sales and profit
category_sales = df.groupby('Category')['Sales'].sum().reset_index()

# %%
category_profit = df.groupby('Category')['Profit'].sum().reset_index()

# %%
category_profit
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
category_sales
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
#merge
category_data = pd.merge(category_sales, category_profit, on='Category')
category_data
# Out:
#           Category        Sales       Profit
# 0        Furniture  741999.7953   18451.2728
# 1  Office Supplies  719047.0320  122490.8008
# 2       Technology  836154.0330  145454.9481

# %%
#profit margin in category
category_data['Profit Margin'] = (category_data['Profit'] / category_data['Sales']) * 100
category_data['Profit Margin']
# Out:
# 0     2.486695
# 1    17.035158
# 2    17.395712
# Name: Profit Margin, dtype: float64

# %%
#visualization of profit
#bar
sns.barplot(x='Category', y='Profit Margin', data=category_data)
plt.title('Profit Margin by Category')
plt.xlabel('Category')
plt.ylabel('Profit Margin')
plt.show()

# %% [markdown]
# # WHAT ALL SECURITY ISSUES AND INSIGHTS U CAN DERIVE BY EDA
#
#
#
#
#
# # 1.	Identifying trends and patterns in customer behaviour, such as buying habits, preferences, and satisfaction levels.
# # 2.	Pinpointing underperforming products, services, or business units that may require improvement or elimination.
# # 3.	Analysing sales data to identify opportunities for increasing revenue, such as cross-selling or upselling.
# # 4.	Identifying gaps or inefficiencies in the supply chain, such as long lead times, high transportation costs, or low supplier performance.
# # 5.	Monitoring and analysing operational metrics to improve efficiency and reduce costs, such as cycle time, defect rate, or machine utilization.
# # 6.	Identifying high-risk customers, such as those with high churn rates, low lifetime value, or high credit risk.
# # 7.	Analyzing marketing data to identify the most effective channels, messages, or campaigns for acquiring and retaining customers.
# # 8.	Identifying fraud or security risks, such as fraudulent transactions, security breaches, or data leaks.
# # 9.	Analyzing financial data to identify trends or anomalies that may indicate financial instability or fraud.
# # 10.	Identifying demographic, social, or economic trends that may impact the business, such as changes in consumer preferences, technological advancements, or regulatory changes.
